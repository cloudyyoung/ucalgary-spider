# %%
import spacy

# %%
nlp = spacy.load("./output/model-best")

doc = nlp("Medicine 300, 303, 320, 330, 340, 345, 350, 360, and 370.")
for ent in doc.ents:
    print(ent)
# Out:
# Medicine 300
# 303
# 320
# 330
# 340
# 345
# 370
