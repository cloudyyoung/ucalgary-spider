# %%
import spacy

# %%
nlp = spacy.load("./output/model-best")
doc = nlp("Computer Science 319 or 331; and Mathematics 211 or 213; and 3 units from Mathematics 249, 265 or 275.")

# %%
for ent in doc.ents:
    print(ent)
# Out:
# Computer Science 319
# 331
# Mathematics
# 211
# 213
# 249
# 265
