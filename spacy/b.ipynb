# %%
import spacy
from spacy import displacy
from spacy.language import Language, Doc
from pymongo import MongoClient
import re

# %%
# Connect to mongodb
client = MongoClient("mongodb://root:password@localhost:27017/")
catalog = client.get_database("catalog")

# %%
# Sort by length of title
subject_codes_docs = list(catalog.get_collection("subject_codes").find())
subject_codes_docs.sort(key=lambda x: len(x["title"]), reverse=True)
subject_codes_map = {doc["title"]: doc["code"] for doc in subject_codes_docs}
subject_codes = [doc["code"] for doc in subject_codes_docs]
subject_codes
# Out:
# ['BIMA',
#  'OBHR',
#  'CMMB',
#  'SCPA',
#  'APLA',
#  'ENEE',
#  'ALMC',
#  'LLAC',
#  'ENSF',
#  'IPHE',
#  'CEST',
#  'ISEC',
#  'EESS',
#  'ASHA',
#  'SUSE',
#  'ENTI',
#  'COMS',
#  'MDPA',
#  'LWFT',
#  'BTMA',
#  'SEDV',
#  'SGMA',
#  'MDBT',
#  'RMIN',
#  'PLMA',
#  'EDBT',
#  'GSXS',
#  'MHST',
#  'EALS',
#  'DEST',
#  'CMDA',
#  'MDGE',
#  'CMCL',
#  'MDCH',
#  'ENEN',
#  'ENMF',
#  'TDST',
#  'CORE',
#  'MDPR',
#  'ENFD',
#  'SCMA',
#  'INTR',
#  'GRST',
#  'EDPS',
#  'BMEN',
#  'ENME',
#  'LAND',
#  'SUST',
#  'ENEL',
#  'COOP',
#  'LAST',
#  'ASL',
#  'ENAE',
#  'ENGO',
#  'ENPE',
#  'ENSC',
#  'OPMA',
#  'INDL',
#  'ENCH',
#  'ENCM',
#  'SENG',
#  'EDER',
#  'REAL',
#  'UNEX',
#  'VETM',
#  'TAP',
#  'PHEN',
#  'SAST',
#  'ENDG',
#  'ENPH',
#  'EAST',
#  'HSOC',
#  'LEAD',
#  'MGST',
#  'TOUR',
#  'INDG',
#  'ENER',
#  'MUPF',
#  'RELS',
#  'ACSC',
#  'QUAC',
#  'ENCI',
#  'ENMG',
#  'POLI',
#  'STST',
#  'ACWR',
#  'CPSC',
#  'CNST',
#  'LWSO',
#  'MDPH',
#  'MUED',
#  'MDSC',
#  'AFST',
#  'ROST',
#  'MRSC',
#  'ESCI',
#  'UBST',
#  'EASC',
#  'SPPH',
#  'PLBI',
#  'BIST',
#  'PPOL',
#  'ARCH',
#  'BCEM',
#  'ANTH',
#  'NEUR',
#  'ASPH',
#  'DATA',
#  'ARHI',
#  'MATH',
#  'SOWK',
#  'KNES',
#  'ARKY',
#  'LING',
#  'NANS',
#  'ENGG',
#  'STAT',
#  'ACCT',
#  'GOPH',
#  'INNO',
#  'PHIL',
#  'INTE',
#  'PSYC',
#  'UNIV',
#  'EDUC',
#  'ASTR',
#  'ECON',
#  'MKTG',
#  'WELL',
#  'FINA',
#  'CHEM',
#  'GEOG',
#  'SOCI',
#  'PLUR',
#  'JPNS',
#  'LANG',
#  'MDCN',
#  'PLAN',
#  'ECOL',
#  'NURS',
#  'PHYS',
#  'GLGY',
#  'HTST',
#  'RUSS',
#  'ENGL',
#  'SPAN',
#  'FNCE',
#  'ITAL',
#  'SCIE',
#  'BIOL',
#  'CHIN',
#  'ZOOL',
#  'NRSG',
#  'GERM',
#  'DSGN',
#  'FREN',
#  'SLAV',
#  'LATI',
#  'DRAM',
#  'MUSI',
#  'DNCE',
#  'GREK',
#  'ERTH',
#  'ARTS',
#  'FILM',
#  'LAW',
#  'ART']

# %%
# Base patterns
subject_code_regex = r"(\w{3,4})"  # ART, MATH
course_number_regex = r"(\d{2}-\d|\d{3}\.\d{1,2}|\d{2,3})"  # 101, 30-1, 599.45
course_code_regex = rf"{subject_code_regex} {course_number_regex}"

# %%
def replace_subject_code(sentence: str, loose: bool=False):
	for subject_code in subject_codes_docs:
		if loose:
			sentence = re.sub(rf"{subject_code["title"]}", rf"{subject_code["code"]}", sentence)
		else:
			sentence = re.sub(rf"{subject_code["title"]} {course_number_regex}", rf"{subject_code["code"]} \1", sentence)
	return sentence

# %%
def process_n_units_of_things(groups):
	units = None
	subject_code = None
	subject_codes = None
	level = None
	is_above = None

	if groups[0]:
		units = int(groups[0])

	if groups[1]:
		sent = replace_subject_code(groups[1], loose=True)
		sent = sent.replace(" or ", ", ")
		subject_codes = [subject_code.strip() for subject_code in sent.split(", ")]

		if len(subject_codes) == 1:
			subject_code = subject_codes[0]
			subject_codes = None

	if groups[2]:
			level = int(groups[2])

	if groups[3]:
			is_above = groups[3] == "above"

	return {
			"units": {
					"required": units,
					**({"subject": subject_code} if subject_code else {}),
					**({"subjects": subject_codes} if subject_codes else {}),
					**({"level": level} if level else {}),
					**({"is_above": is_above} if is_above else {})
			}
	}

# %%
# Patterns
patterns = [
    {
        "regex": rf"^{course_code_regex}\.?$",  # ANTH 201.
        "process": lambda groups: {"and": [{"course": groups[0] + groups[1]}]},
    },
    {
        "regex": rf"^{course_code_regex} and {course_number_regex}\.?$",  # ANTH 201 and 311.
        "process": lambda groups: {
            "and": [
                {"course": groups[0] + groups[1]},
                {"course": groups[0] + groups[2]},
            ]
        },
    },
    {
        "regex": rf"^{course_code_regex} and {course_code_regex}\.?$",  # ANTH 201 and MATH 311.
        "process": lambda groups: {
            "and": [
                {"course": groups[0] + groups[1]},
                {"course": groups[2] + groups[3]},
            ]
        },
    },
    {
        "regex": rf"^{course_code_regex} or {course_number_regex}\.?$",  # ANTH 201 or 311.
        "process": lambda groups: {
            "or": [
                {"course": groups[0] + groups[1]},
                {"course": groups[0] + groups[2]},
            ]
        },
    },
    {
        "regex": rf"^{course_code_regex} or {course_code_regex}\.?$",  # ANTH 201 or MATH 311.
        "process": lambda groups: {
            "or": [
                {"course": groups[0] + groups[1]},
                {"course": groups[2] + groups[3]},
            ]
        },
    },
    {
        "regex": rf"^{subject_code_regex} ((?:{course_number_regex})(?:, {course_number_regex})+)(?:, and | and |, ){course_number_regex}\.?$",  # ANTH 201, 311, 329, ..., 401 and 411.
        "process": lambda groups: {
            "and": [
                {"course": groups[0] + number}
                for number in list(groups[1].split(", ")) + [groups[-1]]
            ]
        },
    },
    {
        "regex": rf"^{subject_code_regex} ((?:{course_number_regex})(?:, {course_number_regex})+)(?:, or | or ){course_number_regex}\.?$",  # ANTH 201, 311, 329, ..., 401 or 411.
        "process": lambda groups: {
            "or": [
                {"course": groups[0] + number}
                for number in list(groups[1].split(", ")) + [groups[-1]]
            ]
        },
    },
    {
        "regex": rf"^{course_code_regex} and either {course_code_regex} or {course_number_regex}\.?$",  # ANTH 201 and either 311 or 329.
        "process": lambda groups: {
            "and": [
                {"course": groups[0] + groups[1]},
                {
                    "or": [
                        {"course": groups[2] + groups[3]},
                        {"course": groups[2] + groups[4]},
                    ]
                },
            ]
        },
    },
    {
        # This regex handles the following cases:
        # "24 units."
        # "18 units at the 200 level."
        # "6 units of English at the 400 level."
        # "6 units of courses labelled English."
        # "9 units in courses labelled Geography at the 300 level or above."
        # "9 units in courses labelled Dance, Drama, Music, Music Performance or School of Creative and Performing Arts."
        "regex": rf"^(\d+) units(?:| (?:of|in)(?: courses labelled | )([a-zA-Z ,]*))(?:| at the (\d+) level(?:| or (above)))\.?$",
        "process": process_n_units_of_things,
    },
]

# %%
sent = "Anthropology 201 and 311."
sent = "Anthropology 210 or 213."
sent = "Anthropology 203."
sent = "Arabic Language and Muslim Cultures 204."
sent = "Astrophysics 401 and Physics 343."
sent = "Biomedical Engineering 103, 309, 310, 319, and 327."
sent = "Computer Science 471 or Data Science 311."
sent = "Drama 200, 223, 225, and 340."
sent = "English 302 and either English 240 or 340."
sent = "Geomatics Engineering 363, 401, 402 and 421."
sent = "Sociology 313, 315, 325, 331, 333."
sent = "Sociology 313, 315, 331, 333."
sent = "Software Engineering 300 or 301."
sent = "Software Engineering 300, 301, or 311."
sent = "24 units."
sent = "18 units at the 200 level."
sent = "6 units of English at the 400 level."
sent = "6 units of courses labelled English."
sent = "9 units in courses labelled Geography at the 300 level or above."
sent = "9 units in courses labelled Dance, Drama, Music, Music Performance or School of Creative and Performing Arts."

sent = replace_subject_code(sent)
print(sent)
print("")

def try_patterns(sent: str, patterns: list):
    for pattern in patterns:
        regex, process = pattern["regex"], pattern["process"]
        matches = re.search(regex, sent)

        if matches:
            result = process(list(matches.groups()))
            return result

result = try_patterns(sent, patterns)
print(result)
# Out:
# 9 units in courses labelled Dance, Drama, Music, Music Performance or School of Creative and Performing Arts.
#
# {'units': {'required': 9, 'subjects': ['DNCE', 'DRAM', 'MUSI', 'MUPF', 'SCPA']}}

# %%
# Get all courses
courses = list(catalog.get_collection("courses").find({"prereq": {"$ne": None}, "career": "Undergraduate Programs"}))

courses_prereq = catalog.get_collection("courses_prereq")
courses_prereq.delete_many({})

for course in courses:
		prereq = course["prereq"]

		if prereq:
			print(prereq)

			prereq = replace_subject_code(prereq)
			result = try_patterns(prereq, patterns)

			print(result)
			print("")

			courses_prereq.insert_one({
					"course": course["code"],
					"prereq_text": prereq,
					"prereq": result
			})
# Out:
# Admission to the Haskayne School of Business and 12 units.
# None
#
# 24 units including Entrepreneurship and Innovation 201.
# None
#
# Admission to the Haskayne School of Business, and Accounting 217.
# None
#
# Admission to the Haskayne School of Business and Accounting 217 and 323.
# None
#
# Admission to the Haskayne School of Business and Accounting 341.
# None
#
# 24 units including Accounting 217 or 301. For certain topics consent of the Haskayne School of Business will also be required.
# None
#
# Admission to the Haskayne School of Business and Accounting 323.
# None
#
# Admission to the Haskayne School of Business, and 54 units including Accounting 217.
# None
#
# Admission to the Haskayne School of Business and Accounting 421.
# None
#
# Admission to the Haskayne School of Business and 54 units including Accounting 341.
# None
#
# Admission to the Haskayne School of Business and 54 units including Accounting 343.
# None
#
# Admission to the Haskayne School of Business and 54 units including Accounting 343.
# None
#
# Admission to the Haskayne School of Business and 54 units including Accounting 361.
# None
#
# Admission to the Haskayne School of Business and 54 units including Accounting 343. For certain topics, consent of the Haskayne School of Business will also be required.
# None
#
# One of Mathematics 249, 265 or 275.
# None
#
# Statistics 321.
# {'and': [{'course': 'STAT321'}]}
#
# Actuarial Science 325 and Statistics 323.
# {'and': [{'course': 'ACSC325'}, {'course': 'STAT323'}]}
#
# Actuarial Science 327; Statistics 323; and 3 units from Mathematics 311, 313, 367 or 375.
# None
#
# Statistics 323.
# {'and': [{'course': 'STAT323'}]}
#
# Statistics 323.
# {'and': [{'course': 'STAT323'}]}
#
# Actuarial Science 327 and Statistics 321.
# {'and': [{'course': 'ACSC327'}, {'course': 'STAT321'}]}
#
# Actuarial Science 325 and Statistics 321.
# {'and': [{'course': 'ACSC325'}, {'course': 'STAT321'}]}
#
# Actuarial Science 327.
# {'and': [{'course': 'ACSC327'}]}
#
# Actuarial Science 327.
# {'and': [{'course': 'ACSC327'}]}
#
# Actuarial Science 327 and Mathematics 323 or Statistics 323; or consent of the Department.
# None
#
# Actuarial Science 327; Statistics 323; 3 units from Mathematics 311, 313, 367 or 375; and 3 units from Computer Science 217, 231, 235 or Data Science 211.
# None
#
# Actuarial Science 327; Statistics 323; and 3 units from Mathematics 311, 313, 367 or 375.
# None
#
# Actuarial Science 327; and Mathematics 323 or Statistics 323.
# None
#
# Actuarial Science 327 and Statistics 323.
# {'and': [{'course': 'ACSC327'}, {'course': 'STAT323'}]}
#
# Actuarial Science 327; Statistics 323; and 3 units from Mathematics 311, 313, 367 or 375.
# None
#
# Actuarial Science 327; Statistics 323; and 3 units from Mathematics 311, 313, 367 or 375.
# None
#
# Consent of the Program Co-ordinator.
# None
#
# Consent of the Program Co-ordinator.
# None
#
# 3 units from the Field of African Studies.
# None
#
# African Studies 201 or 301; and 3 units from the Field of African Studies.
# None
#
# 9 units from the Field of African Studies, of which, 3 units must be from African Studies 201, 301, Anthropology 317, 320.
# None
#
# Consent of the School of Languages, Linguistics, Literatures and Cultures.
# None
#
# Arabic Language and Muslim Cultures 202.
# {'and': [{'course': 'ALMC202'}]}
#
# Arabic Language and Muslim Cultures 204.
# {'and': [{'course': 'ALMC204'}]}
#
# Arabic Language and Muslim Cultures 301.
# {'and': [{'course': 'ALMC301'}]}
#
# Arabic Language and Muslim Cultures 204.
# {'and': [{'course': 'ALMC204'}]}
#
# Arabic Language and Muslim Cultures 204.
# {'and': [{'course': 'ALMC204'}]}
#
# Arabic Language and Muslim Cultures 204.
# {'and': [{'course': 'ALMC204'}]}
#
# Arabic Language and Muslim Cultures 303.
# {'and': [{'course': 'ALMC303'}]}
#
# Arabic Language and Muslim Cultures 331.
# {'and': [{'course': 'ALMC331'}]}
#
# Arabic Language and Muslim Cultures 331.
# {'and': [{'course': 'ALMC331'}]}
#
# Arabic Language and Muslim Cultures 204.
# {'and': [{'course': 'ALMC204'}]}
#
# Arabic Language and Muslim Cultures 204.
# {'and': [{'course': 'ALMC204'}]}
#
# Arabic Language and Muslim Cultures 204.
# {'and': [{'course': 'ALMC204'}]}
#
# Arabic Language and Muslim Cultures 204.
# {'and': [{'course': 'ALMC204'}]}
#
# Arabic Language and Muslim Cultures 204.
# {'and': [{'course': 'ALMC204'}]}
#
# The corresponding language in Arabic Language and Muslim Cultures 343.
# None
#
# The corresponding language in Arabic Language and Muslim Cultures 343.
# None
#
# The corresponding language in Arabic Language and Muslim Cultures 343.
# None
#
# The corresponding language in Arabic Language and Muslim Cultures 343.
# None
#
# The corresponding language in Arabic Language and Muslim Cultures 343.
# None
#
# Arabic Language and Muslim Cultures 204.
# {'and': [{'course': 'ALMC204'}]}
#
# Arabic Language and Muslim Cultures 204.
# {'and': [{'course': 'ALMC204'}]}
#
# Arabic Language and Muslim Cultures 301.
# {'and': [{'course': 'ALMC301'}]}
#
# Consent of the School of Languages, Linguistics, Literatures and Cultures.
# None
#
# 3 units in a course labelled Arabic Language and Muslim Cultures at the 300 level or above.
# {'units': {'required': 3, 'subject': 'a course labelled ALMC', 'level': 300, 'is_above': True}}
#
# 3 units from Anthropology 201, Archaeology 203, Biology 241, 205.
# None
#
# Anthropology 201 or Archaeology 203.
# {'or': [{'course': 'ANTH201'}, {'course': 'ARKY203'}]}
#
# Anthropology 210 or 213.
# {'or': [{'course': 'ANTH210'}, {'course': 'ANTH213'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 201.
# {'and': [{'course': 'ANTH201'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# 3 units from Anthropology 203, Development Studies 201, Indigenous Studies 201.
# None
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Admission to the BA or BSc Anthropology and consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# 3 units from Anthropology 210, 213, 346, 355 or courses labelled Indigenous Studies.
# None
#
# Anthropology 391 or 490.
# {'or': [{'course': 'ANTH391'}, {'course': 'ANTH490'}]}
#
# Anthropology 309 and 311.
# {'and': [{'course': 'ANTH309'}, {'course': 'ANTH311'}]}
#
# Anthropology 201 and 311.
# {'and': [{'course': 'ANTH201'}, {'course': 'ANTH311'}]}
#
# Anthropology 321.
# {'and': [{'course': 'ANTH321'}]}
#
# Anthropology 201 and 311.
# {'and': [{'course': 'ANTH201'}, {'course': 'ANTH311'}]}
#
# Anthropology 323.
# {'and': [{'course': 'ANTH323'}]}
#
# Anthropology 203, 391 and 393, or consent of the Department.
# None
#
# Anthropology 201 and 311.
# {'and': [{'course': 'ANTH201'}, {'course': 'ANTH311'}]}
#
# Anthropology 341.
# {'and': [{'course': 'ANTH341'}]}
#
# Anthropology 201 and 305.
# {'and': [{'course': 'ANTH201'}, {'course': 'ANTH305'}]}
#
# Anthropology 341.
# {'and': [{'course': 'ANTH341'}]}
#
# Anthropology 201 and 311.
# {'and': [{'course': 'ANTH201'}, {'course': 'ANTH311'}]}
#
# Anthropology 203 and 3 units in courses labelled Anthropology at the 300-level or above.
# None
#
# Anthropology 343.
# {'and': [{'course': 'ANTH343'}]}
#
# Anthropology 203, 391 and 393, or consent of the Department.
# None
#
# 3 units from Anthropology 379, Geography 351 or 452.
# None
#
# Anthropology 203.
# {'and': [{'course': 'ANTH203'}]}
#
# Anthropology 203, an additional 3 units of a course labelled Anthropology at the 300 level or above and consent of the Department.
# None
#
# Anthropology 201 and consent of the Department.
# None
#
# 60 units including Anthropology 350 and consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Anthropology 201 and 305.
# {'and': [{'course': 'ANTH201'}, {'course': 'ANTH305'}]}
#
# Anthropology 413.
# {'and': [{'course': 'ANTH413'}]}
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Anthropology 413 and admission to the Anthropology Honours Program.
# None
#
# Anthropology 411 and admission to the Anthropology Honours Program.
# None
#
# Anthropology 201 and 305.
# {'and': [{'course': 'ANTH201'}, {'course': 'ANTH305'}]}
#
# Admission to the BSc Anthropology Honours program.
# None
#
# Admission to the BSc Anthropology Honours program.
# None
#
# Admission to the BSc Anthropology Honours program.
# None
#
# Architecture 201 or Architectural Studies 201.
# None
#
# Architecture 201 or Architectural Studies 201.
# None
#
# Architecture 406 or Architectural Studies 431.
# None
#
# Admission to the Minor in Architectural Studies or the Master of Architecture Programs.
# None
#
# Admission to the Minor in Architectural Studies or the Master of Architecture Programs.
# None
#
# Admission to the Minor in Architectural Studies or the Master of Architecture Programs.
# None
#
# Admission to the Minor in Architectural Studies or the Master of Architecture Programs.
# None
#
# Admission to the Minor in Architectural Studies or the Master of Architecture Programs.
# None
#
# Admission to the Minor in Architectural Studies or the Master of Architecture Programs.
# None
#
# Architecture 504, 506 and admission to the Minor in Architectural Studies or the Master of Architecture Programs.
# None
#
# Architecture 504, 506 and admission to the Minor in Architectural Studies or the Master of Architecture Programs.
# None
#
# Admission to the Visual Studies or Art History major programs.
# None
#
# 6 units of courses labelled Art History.
# {'units': {'required': 6, 'subject': 'ARHI'}}
#
# Three full-course equivalents in Art History or consent of the Department.
# None
#
# Three full-course equivalents in Art History or consent of the Department.
# None
#
# 3 units from Art History 331, 333, 357 and 3 additional units of courses labelled Art History at the 300 level or above.
# None
#
# 6 units in courses labeled Art History at the 300 level or above.
# {'units': {'required': 6, 'subject': 'courses labeled ARHI', 'level': 300, 'is_above': True}}
#
# 18 units of courses labelled Art History at the 300 level or above and consent of the Department.
# None
#
# 18 units of courses labelled Art History at the 300 level or above and consent of the Department.
# None
#
# 18 units of courses labelled Art History at the 300 level or above and consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Archaeology 201 or 205.
# {'or': [{'course': 'ARKY201'}, {'course': 'ARKY205'}]}
#
# Archaeology 201 or 205.
# {'or': [{'course': 'ARKY201'}, {'course': 'ARKY205'}]}
#
# Archaeology 201 or 205 or consent of the Department.
# None
#
# Archaeology 341 and 343 or consent of the Department.
# None
#
# Geography 313.
# {'and': [{'course': 'GEOG313'}]}
#
# Archaeology 201.
# {'and': [{'course': 'ARKY201'}]}
#
# Archaeology 201.
# {'and': [{'course': 'ARKY201'}]}
#
# 3 units from Archaeology 201, 205, 303.
# None
#
# ARKY 201 or consent of the Department.
# None
#
# Archaeology 201 or consent of the Department.
# None
#
# Archaeology 201 or 203.
# {'or': [{'course': 'ARKY201'}, {'course': 'ARKY203'}]}
#
# History 354 or 3 units labelled Archaeology or Urban Studies.
# None
#
# Archaeology 201 or 205 or consent of the Department
# None
#
# Archaeology 201.
# {'and': [{'course': 'ARKY201'}]}
#
# Archaeology 201 and completion of at least 60 units.
# None
#
# 3 units from Archaeology 201, Geography 211, 310, Geology 201, 209.
# None
#
# Archaeology 201 or consent of the Department.
# None
#
# Archaeology 201.
# {'and': [{'course': 'ARKY201'}]}
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Archaeology 451 or consent of the Department.
# None
#
# Archaeology 451.
# {'and': [{'course': 'ARKY451'}]}
#
# Archaeology 201 and 306.
# {'and': [{'course': 'ARKY201'}, {'course': 'ARKY306'}]}
#
# Archaeology 201 and 3 units of courses labelled Archaeology at the 400 level or above.
# None
#
# Archaeology 321 or consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# 6 units (1.0 full-course equivalent) from Archaeology 341, 343, 345, 347.
# None
#
# Anthropology 309 or 350, or Archaeology 417.
# None
#
# Admission to BA or BSc Archaeology Honours program and consent of the Department.
# None
#
# Admission to BA or BSc Archaeology Honours program and consent of the Department.
# None
#
# Admission to BA or BSc Archaeology Honours program and consent of the Department.
# None
#
# Archaeology 451.
# {'and': [{'course': 'ARKY451'}]}
#
# Archaeology 451.
# {'and': [{'course': 'ARKY451'}]}
#
# 9 units Anthropology 201, 350, Archaeology 555 and admission to the Archaeology or Anthropology major.
# None
#
# Admission to Archaeology BSc Honours program and consent of the Department.
# None
#
# Admission to Archaeology BSc Honours program and consent of the Department.
# None
#
# Admission to Archaeology BSc Honours program and consent of the Department.
# None
#
# Admission to the BA or BSc Archaeology and consent of the Department.
# None
#
# Admission to Archaeology BA Honours program and consent of the Department.
# None
#
# Admission to Archaeology BA Honours program and consent of the Department.
# None
#
# Admission to Archaeology BA Honours program and consent of the Department.
# None
#
# Art 003 or consent of the Department.
# None
#
# Art 003 or consent of the Department.
# None
#
# Art 003 or consent of the Department.
# None
#
# Art 209 or consent of the Department.
# None
#
# Art 241.
# {'and': [{'course': 'ART241'}]}
#
# Art 235
# {'and': [{'course': 'ART235'}]}
#
# Art 235.
# {'and': [{'course': 'ART235'}]}
#
# 3 units of courses labelled Art.
# {'units': {'required': 3, 'subject': 'ART'}}
#
# 3 units of courses labelled Art.
# {'units': {'required': 3, 'subject': 'ART'}}
#
# 3 units in courses labelled Art.
# {'units': {'required': 3, 'subject': 'ART'}}
#
# 3 units in courses labelled Art.
# {'units': {'required': 3, 'subject': 'ART'}}
#
# 15 units of courses labelled Art.
# {'units': {'required': 15, 'subject': 'ART'}}
#
# 15 units of courses labelled Art.
# {'units': {'required': 15, 'subject': 'ART'}}
#
# 3 units in courses labelled Art.
# {'units': {'required': 3, 'subject': 'ART'}}
#
# Art 336.
# {'and': [{'course': 'ART336'}]}
#
# 3 units in courses labelled Art.
# {'units': {'required': 3, 'subject': 'ART'}}
#
# Art 235.
# {'and': [{'course': 'ART235'}]}
#
# Art 235.
# {'and': [{'course': 'ART235'}]}
#
# Art 235.
# {'and': [{'course': 'ART235'}]}
#
# Art 241.
# {'and': [{'course': 'ART241'}]}
#
# Art 241.
# {'and': [{'course': 'ART241'}]}
#
# Art 241.
# {'and': [{'course': 'ART241'}]}
#
# Art 345.
# {'and': [{'course': 'ART345'}]}
#
# Art 231 or 241.
# {'or': [{'course': 'ART231'}, {'course': 'ART241'}]}
#
# Art 231 or 241.
# {'or': [{'course': 'ART231'}, {'course': 'ART241'}]}
#
# Art 231 or 241
# {'or': [{'course': 'ART231'}, {'course': 'ART241'}]}
#
# 6 units of courses labelled Art at the 300 level.
# {'units': {'required': 6, 'subject': 'ART', 'level': 300}}
#
# Art 361.
# {'and': [{'course': 'ART361'}]}
#
# Art 233.
# {'and': [{'course': 'ART233'}]}
#
# Art 233.
# {'and': [{'course': 'ART233'}]}
#
# 12 units of courses labelled Art.
# {'units': {'required': 12, 'subject': 'ART'}}
#
# Art 235 and 315.
# {'and': [{'course': 'ART235'}, {'course': 'ART315'}]}
#
# Art 314
# {'and': [{'course': 'ART314'}]}
#
# 15 units of courses labelled Art at the 300 level including 3 units from Art 313, 331, 319, 323, 334.
# None
#
# 15 units of courses labelled Art at the 300 level, including 3 units from Art 313, 319, 323, 331, 334, 336.
# None
#
# One of Art 335, 336, 337, or 338.
# None
#
# 15 units of courses labelled Art at the 300 level including Art 332 or 338.
# None
#
# 15 units of courses labelled Art at the 300 level, including 3 units from Art 341, 343, 345, 347, 349.
# None
#
# Art 231 or 241.
# {'or': [{'course': 'ART231'}, {'course': 'ART241'}]}
#
# 15 units of courses labelled Art at the 300 level including 3 units from Art 351 or 353.
# None
#
# Consent of Department.
# None
#
# Consent of Department or admission to the Honours Program.
# None
#
# Consent of Department.
# None
#
# Enrollment in the BFA Honours (Art) program and Art 461.
# None
#
# 15 units of courses labelled Art at the 300 level including Art History 333.
# None
#
# One of Art History 331 or 333; and an additional 3 units (0.5 full course-equivalents) of Art History courses at the 300 level.
# None
#
# 15 units of courses labelled Art at the 300 level, including 3 units from Art 373, 377, 379.
# None
#
# Art 233.
# {'and': [{'course': 'ART233'}]}
#
# 15 units of courses labelled Art at the 300 level including 3 units from Art 381 or 383.
# None
#
# Art 399 and admission to the BFA or BFA Honours in Visual Studies.
# None
#
# Art 331 or consent of the Department.
# None
#
# 15 units of courses labelled Art at the 300 level including 3 units from Art 323, 315, 317, 321.
# None
#
# ART 251 or consent of the Department.
# None
#
# 12 units of courses labelled Art at the 300 level or above.
# {'units': {'required': 12, 'subject': 'ART', 'level': 300, 'is_above': True}}
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Admission to the BFA Honours Visual Studies Program.
# None
#
# Admission to the BFA Honours Visual Studies Program.
# None
#
# Admission to the BFA Honours Visual Studies Program.
# None
#
# Admission to Honours in Visual Studies and consent of the Department.
# None
#
# Admission to Honours in Visual Studies and Art 561.
# None
#
# Art 465.
# {'and': [{'course': 'ART465'}]}
#
# Admission to Honours in Visual Studies and consent of the Department.
# None
#
# 3 units of courses labelled Art at the 400 level and admission to the BFA or BFA Honours in Visual Studies.
# None
#
# Art 499 or consent of the Department.
# None
#
# Third year standing and consent of the faculty.
# None
#
# Acceptance to a recognized academic internship or field placement program and approval of the Faculty of Arts.
# None
#
# Admission to the BA Multidisciplinary and completion of 75 units.
# None
#
# 48 units and consent of the Instructor.
# None
#
# Arts 507 or Communication and Culture 507 or Science 511 and consent of the instructor.
# None
#
# Admission to the Arts and Science Honours Academy Program.
# None
#
# Admission to the Arts and Science Honours Academy Program.
# None
#
# Admission to the Arts and Science Honours Academy Program.
# None
#
# Arts and Science Honours Academy 220 and admission to the Arts and Science Honours Academy.
# None
#
# Arts and Science Honours Academy 222 or 220 and admission to the Arts and Science Honours Academy.
# None
#
# Arts and Science Honours Academy 321 and admission to the Arts and Science Honours Academy.
# None
#
# Arts and Science Honours Academy 322 and admission to the Arts and Science Honours Academy.
# None
#
# Arts and Sciences Honours Academy 421 and admission to the Arts and Science Honours Academy.
# None
#
# Arts and Science Honours Academy 422 or 421 and admission to the Arts and Science Honours Academy.
# None
#
# American Sign Language 201 or consent of the Department.
# None
#
# Physics 211 or 221 or 227 or Engineering 202.
# None
#
# 3 units from Physics 211, 221, 227 or Engineering 202; and 3 units from Mathematics 267 or 277.
# None
#
# Astrophysics 213 or 305.
# {'or': [{'course': 'ASPH213'}, {'course': 'ASPH305'}]}
#
# Physics 229 or 325; Physics 259 or 355; Mathematics 376 or 375; and Astrophysics 213 or 305.
# None
#
# Astrophysics 213 or 305; Physics 229 or 325; Physics 341 or Engineering 349; and Mathematics 375 or 376.
# None
#
# Astrophysics 213 or 305; Physics 229 or 325; Physics 341; and Mathematics 376 or 375.
# None
#
# Astrophysics 403, Physics 499.
# None
#
# Astrophysics 401 and Physics 343.
# {'and': [{'course': 'ASPH401'}, {'course': 'PHYS343'}]}
#
# Astrophysics 401 and Physics 343.
# {'and': [{'course': 'ASPH401'}, {'course': 'PHYS343'}]}
#
# Astrophysics 401 and Physics 343.
# {'and': [{'course': 'ASPH401'}, {'course': 'PHYS343'}]}
#
# Astronomy 213 or Astrophysics 213.
# {'or': [{'course': 'ASTR213'}, {'course': 'ASPH213'}]}
#
# Astrophysics 401 and Physics 343.
# {'and': [{'course': 'ASPH401'}, {'course': 'PHYS343'}]}
#
# Pure Mathematics 30 or Mathematics 30 and Physics 30.
# None
#
# Astronomy 211.
# {'and': [{'course': 'ASTR211'}]}
#
# Chemistry 351.
# {'and': [{'course': 'CHEM351'}]}
#
# Chemistry 351, Biology 311 and admission to a Major offered by the Department of Biological Sciences or the Neuroscience Major or a primary concentration in Biological Sciences in either the Natural Sciences or Environmental Science Major. Or, Chemistry 351, and Medical Science 341, and admission to either the Biomedical Science or Bioinformatics Major.
# None
#
# Biochemistry 393 and one of Chemistry 353 or 355.
# None
#
# Biochemistry 401 and 471.
# {'and': [{'course': 'BCEM401'}, {'course': 'BCEM471'}]}
#
# Biochemistry 393; and Chemistry 353 or 355.
# None
#
# Cellular, Molecular and Microbial Biology 411, Biochemistry 411 and 471.
# None
#
# Biology 331; Biochemistry 341 or 393; and Chemistry 353 or 355.
# None
#
# Chemistry 353 or 355; and Biochemistry 341 or 393.
# None
#
# Biochemistry 341 or 393; and Chemistry 353 or 355; and 3 units from Mathematics 249, 251, 265, 275, 281, or Applied Mathematics 217; and 3 units from Mathematics 253, 267, 277, 283, 211, 213, or Applied Mathematics 219; and Physics 211 or 221, and 223.
# None
#
# 54 units and consent of the Department.
# None
#
# 54 units and consent of the Department.
# None
#
# 54 units and consent of the Department.
# None
#
# 54 units and consent of the Department.
# None
#
# 54 units and consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# Biochemistry 341 or 393; Chemistry 311, 321 and 351.
# None
#
# Biochemistry 341 or 393.
# {'or': [{'course': 'BCEM341'}, {'course': 'BCEM393'}]}
#
# Biochemistry 393.
# {'and': [{'course': 'BCEM393'}]}
#
# Biochemistry 341 or 393; and Biochemistry 471 or Chemistry 371.
# None
#
# Biochemistry 341 or 393; and Biochemistry 471 or Chemistry 371.
# None
#
# Biochemistry 431 and 471.
# {'and': [{'course': 'BCEM431'}, {'course': 'BCEM471'}]}
#
# Biochemistry 341 or 393; and Biology 331.
# None
#
# 6 units of courses labelled Biochemistry.
# {'units': {'required': 6, 'subject': 'BCEM'}}
#
# Biochemistry 341 or 393; and Biochemistry 471 or Chemistry 371.
# None
#
# Biology 20 and admission to an Indigenous Pathway program.
# None
#
# Biology 30 or 212 and Chemistry 30 or 212.
# None
#
# Biology 241..
# None
#
# One of Biology 30 or 205 or 212 or 241.
# None
#
# 24 units.
# {'units': {'required': 24}}
#
# Biology 205 or 241.
# {'or': [{'course': 'BIOL205'}, {'course': 'BIOL241'}]}
#
# Biology 241 and 243.
# {'and': [{'course': 'BIOL241'}, {'course': 'BIOL243'}]}
#
# Biology 241 and 243.
# {'and': [{'course': 'BIOL241'}, {'course': 'BIOL243'}]}
#
# Biology 241 and 243.
# {'and': [{'course': 'BIOL241'}, {'course': 'BIOL243'}]}
#
# Biology 311.
# {'and': [{'course': 'BIOL311'}]}
#
# Biology 313 and Botany 303.
# None
#
# Biology 241 and 243.
# {'and': [{'course': 'BIOL241'}, {'course': 'BIOL243'}]}
#
# 24 units.
# {'units': {'required': 24}}
#
# Biology 313, 315.
# None
#
# Biology 313 and 315.
# {'and': [{'course': 'BIOL313'}, {'course': 'BIOL315'}]}
#
# Biology 313 and 331.
# {'and': [{'course': 'BIOL313'}, {'course': 'BIOL331'}]}
#
# Biology 313.
# {'and': [{'course': 'BIOL313'}]}
#
# Biology 313; and 3 units from Botany 303, Biology 371 or Plant Biology 403.
# None
#
# Biology 331.
# {'and': [{'course': 'BIOL331'}]}
#
# Biology 331.
# {'and': [{'course': 'BIOL331'}]}
#
# Biochemistry 341 or 393; and Zoology 463 or Medical Science 404.
# None
#
# Biology 501 (Medical Science 501).
# None
#
# Biology 331; and Biochemistry 341 or 393.
# None
#
# 54 units and consent of the Department.
# None
#
# 54 units and consent of the Department.
# None
#
# 54 units and consent of the Department.
# None
#
# 54 units and consent of the Department.
# None
#
# Biochemistry 341 or 393; and Biology 331 or Medical Science 351.
# None
#
# Consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# 3 units from Zoology 375, 401 or 435.
# None
#
# 54 units and consent of the Department.
# None
#
# Cellular, Molecular and Microbial Biology 411.
# {'and': [{'course': 'CMMB411'}]}
#
# Biology 311 and 331; and 3 units from Cellular, Molecular and Microbial Biology 411, Biochemistry 401 or 443.
# None
#
# Cellular, Molecular and Microbial Biology 411.
# {'and': [{'course': 'CMMB411'}]}
#
# Biology 311, 331, Cellular, Molecular and Microbial Biology 343; and 3 units from Cellular, Molecular and Microbial Biology 411, Biochemistry 431 or 443.
# None
#
# 72 units and consent of the Department.
# None
#
# Biomedical Engineering 103, 309, 319, and 327.
# {'and': [{'course': 'BMEN103'}, {'course': 'BMEN309'}, {'course': 'BMEN319'}, {'course': 'BMEN327'}]}
#
# Admission to the Minor or Major in Biomedical Engineering.
# None
#
# Admission to the Minor or Major in Biomedical Engineering.
# None
#
# Mathematics 277; and either Engineering 201 and Chemistry 209; or Engineering 204 and 212
# None
#
# Engineering 202 and Mathematics 277.
# {'and': [{'course': 'ENGG202'}, {'course': 'MATH277'}]}
#
# Biomedical Engineering 381.
# {'and': [{'course': 'BMEN381'}]}
#
# Engineering 225, Mathematics 277 and Physics 259.
# None
#
# Mathematics 375 and admission to the Minor or Major in Biomedical Engineering.
# None
#
# Biomedical Engineering 300 and 322.
# {'and': [{'course': 'BMEN300'}, {'course': 'BMEN322'}]}
#
# Engineering 200 and Biomedical Engineering 301.
# {'and': [{'course': 'ENGG200'}, {'course': 'BMEN301'}]}
#
# Biomedical Engineering 468.
# {'and': [{'course': 'BMEN468'}]}
#
# Biomedical Engineering 388.
# {'and': [{'course': 'BMEN388'}]}
#
# Fourth- or fifth-year standing in Schulich School of Engineering and admission to the Biomedical Engineering minor.
# None
#
# Fourth- or fifth-year standing in Schulich School of Engineering and admission to the Biomedical Engineering minor.
# None
#
# Fourth- or fifth-year standing in Schulich School of Engineering and admission to the Biomedical Engineering minor.
# None
#
# Fourth- or fifth-year standing in Schulich School of Engineering, admission to the Biomedical Engineering minor, and consent of the project supervisor.
# None
#
# Fourth- or fifth-year standing in Schulich School of Engineering and consent of the department.
# None
#
# Fourth- or fifth-year standing in Schulich School of Engineering and consent of the department.
# None
#
# Fourth- or fifth-year standing in Schulich School of Engineering and consent of the department.
# None
#
# Fourth- or fifth-year standing in Schulich School of Engineering.
# None
#
# Fourth- or fifth-year standing in Schulich School of Engineering.
# None
#
# Mathematics 375.
# {'and': [{'course': 'MATH375'}]}
#
# Consent of the BMES Director or designate.
# None
#
# Consent of the BMES Director or designate.
# None
#
# Consent of the BMES Director or designate.
# None
#
# Engineering 349.
# {'and': [{'course': 'ENGG349'}]}
#
# Engineering 349.
# {'and': [{'course': 'ENGG349'}]}
#
# Fourth- or fifth-year standing in Schulich School of Engineering.
# None
#
# Biology 233 or 243 and 331 and one of Biochemistry 341 or 393.
# None
#
# Completion of at least 15 full-course equivalents and consent of the department .
# None
#
# Completion of at least 15 full-course equivalents and consent of the department .
# None
#
# Completion of at least 15 full-course equivalents and consent of the department .
# None
#
# Completion of at least 15 full-course equivalents and consent of the Department.
# None
#
# Fourth-year standing and consent of the Department.
# None
#
# Completion of at least 15 full-course equivalents and consent of the Department.
# None
#
# Botany 327.
# None
#
# Biology 331 and Botany 303 or 321.
# None
#
# Admission to the Haskayne School of Business, Management Studies 217 and Strategy and Global Management 217.
# None
#
# 30 units.
# {'units': {'required': 30}}
#
# Admission to the Haskayne School of Business and Business Technology Management 317.
# None
#
# Admission to the Haskayne School of Business and Business Technology Management 317.
# None
#
# Admission to the Haskayne School of Business and Business Technology Management 317.
# None
#
# Admission to the Haskayne School of Business, Business Technology Management 317 and one senior Business Technology Management course.
# None
#
# Admission to the Haskayne School of Business and Business Technology Management 317.
# None
#
# Admission to the Haskayne School of Business and Business Technology Management 317.
# None
#
# Admission to the Haskayne School of Business and Business Technology Management 317.
# None
#
# Admission to the Haskayne School of Business and Business Technology Management 317.
# None
#
# Admission to the Haskayne School of Business and Business Technology Management 317.
# None
#
# Admission to the Haskayne School of Business and Business Technology Management 317.
# None
#
# Admission to the Haskayne School of Business and Business Technology Management 317. For certain topics, consent of the Haskayne School of Business will also be required. required.
# None
#
# Chemistry 30 or 212 (or Continuing Education - Chemistry 2) and one of Mathematics 30-1, 212 or Mathematics 2 (offered by Continuing Education).
# None
#
# Chemistry 30 or 212 (or Continuing Education - Chemistry 2) and one of Mathematics 30-1, 212 or Mathematics 2 (offered by Continuing Education).
# None
#
# Chemistry 30 or 212 (or Continuing Education - Chemistry 2) and one of Mathematics 30-1 or Mathematics 2 (offered by Continuing Education) and admission to the Schulich School of Engineering.
# None
#
# A grade of 80 per cent or higher in Chemistry 30 (or a grade of \"B+\" or higher in one of Chemistry 212 or Continuing Education - Chemistry 2) and one of Mathematics 30-1, 212 or Mathematics 2 (offered by Continuing Education).
# None
#
# Chemistry 20 and admission to an Indigenous Pathway program.
# None
#
# Chemistry 201 or 211.
# {'or': [{'course': 'CHEM201'}, {'course': 'CHEM211'}]}
#
# Chemistry 201 or 211; and 203 or 213; and one of Mathematics 249, 265 or 275.
# None
#
# Chemistry 311.
# {'and': [{'course': 'CHEM311'}]}
#
# 3 units from Chemistry 203, 209, 213 or Engineering 204.
# None
#
# Chemistry 201 or 211 and 203 or 213.
# None
#
# Chemistry 201 or 211 and 203 or 213 and 331.
# None
#
# Chemistry 201 or 211; and 203 or 213.
# None
#
# Chemistry 351.
# {'and': [{'course': 'CHEM351'}]}
#
# Chemistry 201 or 211; and 203 or 213; and 351 and admission to the Chemistry major, Applied Chemistry major or Chemical Physics major.
# None
#
# Chemistry 209 or Engineering 204; or Chemistry 201 or 211, and 203 or 213.
# None
#
# Chemistry 201 or 211; and 203 or 213; Physics 223 or admission to a Major program offered by the Department of Physics and Astronomy and 6 units of Physics; and Mathematics 267 or 277.
# None
#
# Chemistry 201 or 211; and 203 or 213; Physics 223 or 355; Mathematics 267 or 277.
# None
#
# Chemistry 209 or Engineering 204; or Chemistry 201 or 211, and 203 or 213.
# None
#
# Chemistry 201 or 211, and 203 or 213, and consent of the Department.
# None
#
# Chemistry 201 or 211, and 203 or 213, and consent of the Department.
# None
#
# Chemistry 201 or 211, and 203 or 213, and consent of the Department.
# None
#
# Chemistry 201 or 211, and 203 or 213, and consent of the Department.
# None
#
# Chemistry 201 or 211, and 203 or 213, and consent of the Department.
# None
#
# Chemistry 209 or Engineering 204; and Chemistry 357.
# None
#
# Chemistry 311[CHEM311] and 315[CHEM315].
# None
#
# Chemistry 333 or 433; and one of 353 or 355; or Chemistry 357 and 409.
# None
#
# Chemistry 353 or 355.
# {'or': [{'course': 'CHEM353'}, {'course': 'CHEM355'}]}
#
# Chemistry 201 or 211; and 203 or 213;, and 351.
# None
#
# Chemistry 201 or 211, and 203 or 213, and 331 or 431.
# None
#
# Chemistry 351; Chemistry 353, or 355.
# None
#
# Chemistry 371 and 373.
# {'and': [{'course': 'CHEM371'}, {'course': 'CHEM373'}]}
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Chemistry 311 and 315.
# {'and': [{'course': 'CHEM311'}, {'course': 'CHEM315'}]}
#
# Chemistry 315 and 373.
# {'and': [{'course': 'CHEM315'}, {'course': 'CHEM373'}]}
#
# Chemistry 331 or 431; and 333 or 433; and one of 353 or 355.
# None
#
# Chemistry 331 or 431; and 333 or 433; and one of 353 or 355.
# None
#
# Chemistry 431, 433 and 453; and admission to the Chemistry major.
# None
#
# Chemistry 311, 321 and 351; and one of Biochemistry 341 or 393.
# None
#
# Chemistry 453.
# {'and': [{'course': 'CHEM453'}]}
#
# Chemistry 351 and 353
# {'and': [{'course': 'CHEM351'}, {'course': 'CHEM353'}]}
#
# Chemistry 453.
# {'and': [{'course': 'CHEM453'}]}
#
# Chemistry 453 and admission to the Chemistry major, Applied Chemistry major or Chemical Physics major.
# None
#
# Chemistry 351, and one of 353 or 355.
# None
#
# Chemistry 371 and 373.
# {'and': [{'course': 'CHEM371'}, {'course': 'CHEM373'}]}
#
# Chemistry 371 and 373.
# {'and': [{'course': 'CHEM371'}, {'course': 'CHEM373'}]}
#
# Chemistry 371 and 373.
# {'and': [{'course': 'CHEM371'}, {'course': 'CHEM373'}]}
#
# Chemistry 209 or Engineering 204; and Chemistry 357 or 379; and Chemical Engineering 427.
# None
#
# Consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# 72 units and consent of the Department.
# None
#
# Cellular, Molecular and Microbial Biology 451 and completion of at least 72 units and consent of the Department.
# None
#
# Cellular, Molecular and Microbial Biology 451 and completion of at least 72 units and consent of the Department.
# None
#
# Cellular, Molecular and Microbial Biology 451 and completion of at least 72 units and consent of the Department.
# None
#
# Biology 311 and 331; and 3 units from Cellular, Molecular and Microbial Biology 411, Biochemistry 443 or 431.
# None
#
# Cellular, Molecular and Microbial Biology 343.
# {'and': [{'course': 'CMMB343'}]}
#
# Cellular, Molecular and Microbial Biology 343.
# {'and': [{'course': 'CMMB343'}]}
#
# Cellular, Molecular and Microbial Biology 411.
# {'and': [{'course': 'CMMB411'}]}
#
# Biochemistry 341 or 393; and Biology 311 or Medical Science 341; and Biology 331 or Medical Science 351; and Cellular, Molecular and Microbial Biology 411 or Medical Science 408.
# None
#
# Cellular, Molecular and Microbial Biology 343 or consent of the Department.
# None
#
# Cellular, Molecular and Microbial Biology 343 and 431.
# {'and': [{'course': 'CMMB343'}, {'course': 'CMMB431'}]}
#
# Cellular, Molecular and Microbial Biology 527 or Medical Science 321.
# {'or': [{'course': 'CMMB527'}, {'course': 'MDSC321'}]}
#
# 48 units and admission to the BCR or BCR-C program.
# None
#
# Canadian Studies 201.
# {'and': [{'course': 'CNST201'}]}
#
# 48 units and admission to the BCR or BCR-C program.
# None
#
# 27 units (4.5 full-course equivalents).
# None
#
# 48 units.
# {'units': {'required': 48}}
#
# 48 units.
# {'units': {'required': 48}}
#
# 54 units (9.0 full-course equivalents).
# None
#
# 24 units.
# {'units': {'required': 24}}
#
# 3 units from Art 361, Communication and Media Studies 313, History 300, Political Science 399 or Sociology 313 and consent of the Department.
# None
#
# 24 units.
# {'units': {'required': 24}}
#
# 24 units.
# {'units': {'required': 24}}
#
# 24 units.
# {'units': {'required': 24}}
#
# 48 units.
# {'units': {'required': 48}}
#
# 48 units.
# {'units': {'required': 48}}
#
# 48 units.
# {'units': {'required': 48}}
#
# 54 units (9.0 full-course equivalents).
# None
#
# 54 units.
# {'units': {'required': 54}}
#
# 54 units (9.0 full-course equivalents).
# None
#
# 48 units.
# {'units': {'required': 48}}
#
# 48 units.
# {'units': {'required': 48}}
#
# 48 units.
# {'units': {'required': 48}}
#
# 54 units.
# {'units': {'required': 54}}
#
# 72 units, including 6 units from courses labeled Canadian Studies.
# None
#
# Admission to the Canadian Studies Honours Program and 3 units from Art 361, Communication and Media Studies 313, History 300, Political Science 399 or Sociology 313.
# None
#
# Admission to the Canadian Studies Honours Program and 3 units from Art 361, Communication and Media Studies 313, History 300, Political Science 399 or Sociology 313.
# None
#
# Communication and Media Studies 201.
# {'and': [{'course': 'COMS201'}]}
#
# 24 units.
# {'units': {'required': 24}}
#
# Communication and Media Studies 201 or Film 201.
# {'or': [{'course': 'COMS201'}, {'course': 'FILM201'}]}
#
# Prerequisite or Corequisite: Communication and Media Studies 201.
# None
#
# Communication and Media Studies 201.
# {'and': [{'course': 'COMS201'}]}
#
# Communication and Media Studies 201.
# {'and': [{'course': 'COMS201'}]}
#
# 54 units.
# {'units': {'required': 54}}
#
# 54 units.
# {'units': {'required': 54}}
#
# Communications Studies 441 or consent of the Associate Dean (Student Affairs).
# None
#
# Communications Studies 201 and consent of the Department.
# None
#
# Communication and Media Studies 313.
# {'and': [{'course': 'COMS313'}]}
#
# 72 units, Community Rehabilitation 487 and admission to BCR, Minor in Community Rehabilitation and Disability Studies, Minor in Adapted and Therapeutic Physical Activity or Concentration in Community Rehabilitation and Disability Studies for Health and Society Majors in the Bachelor of Health Sciences program.
# None
#
# 54 units and admission to BCR, Minor in Community Rehabilitation and Disability Studies, Minor in Adapted and Therapeutic Physical Activity or Concentration in Community Rehabilitation and Disability Studies for Health and Society Majors in the Bachelor of Health Sciences program.
# None
#
# Communication and Media Studies 201.
# {'and': [{'course': 'COMS201'}]}
#
# Communications Studies 201[COMS201].
# None
#
# Communications Studies 201.
# None
#
# 3 units from Communication and Media Studies 363, 383, 369.
# None
#
# Communication and Media Studies 369.
# {'and': [{'course': 'COMS369'}]}
#
# Communication and Media Studies 371 or Communications Studies 371.
# None
#
# Communication and Media Studies 371 or Communications Studies 371.
# None
#
# Communication and Media Studies 371.
# {'and': [{'course': 'COMS371'}]}
#
# Community Rehabilitation 594.
# {'and': [{'course': 'CORE594'}]}
#
# Consent of the Program.
# None
#
# Admission to the BCR-C distance program.
# None
#
# Community Rehabilitation 596 or 597 and admission to the BCR-C distance program.
# None
#
# Communication and Media Studies 371.
# {'and': [{'course': 'COMS371'}]}
#
# Communication and Media Studies 203 and 371.
# {'and': [{'course': 'COMS203'}, {'course': 'COMS371'}]}
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Communication and Media Studies 371 or 435.
# {'or': [{'course': 'COMS371'}, {'course': 'COMS435'}]}
#
# 78 units, including Communication and Media Studies 371 and 381 and admission to a major or minor program in Communication and Media Studies.
# None
#
# One of Communication and Culture 313 or Communication and Media Studies 313 or Communications Studies 313; and one of Communication and Media Studies 369, 371,381, 393, Communications Studies 369, 371, 381, or 393.
# None
#
# Communication and Media Studies 201; and an additional 3 units of a course labelled Communication and Media Studies and admission to a majors or minor program in the Department of Communication, Media and Film and consent of the Department.
# None
#
# Communication and Media Studies 201; and an additional 3 units of a course labelled Communication and Media Studies and admission to a majors or minor program in the Department of Communication, Media and Film and consent of the Department.
# None
#
# Communication and Media Studies 201; and an additional 3 units of a course labelled Communication and Media Studies and admission to a majors or minor program in the Department of Communication, Media and Film and consent of the Department.
# None
#
# Communications Studies 367 or consent of the Faculty.
# None
#
# Admission to the Bachelor of Communications Studies program or Bachelor of Film Studies program. One of Communications Studies 369, 371, 381 or one of Film 321, 323, 331 or 333, and first year of SAIT Communication Arts diploma program or equivalent.
# None
#
# Admission to the Bachelor of Communications Studies program or Bachelor of Film Studies program. One of Communications Studies 369, 371, 381 or one of Film 321, 323, 331 or 333, and first year of SAIT Communication Arts diploma program or equivalent.
# None
#
# Admission to the Bachelor of Communications Studies program or Bachelor of Film Studies program. One of Communications Studies 369, 371, 381 or one of Film 321, 323, 331 or 333, and first year of SAIT Communication Arts diploma program or equivalent.
# None
#
# 3 units from Communication and Media Studies 369, 371, 381; or 3 units from Film 321, 323, 331, 333; and first year of an applicable diploma program from SAIT or an approved equivalent, and admission to the Bachelor of Communication and Media Studies program or Bachelor of Film Studies program.
# None
#
# Communication and Media Studies 313 or Communications Studies 313 and admission to the Honours Program.
# None
#
# Communication and Media Studies 313 or Communications Studies 313 and admission to the Honours Program.
# None
#
# Communication and Media Studies 313 or Communications Studies 313 and admission to the Honours Program.
# None
#
# 78 units, including Communication and Media Studies 313, 369, 371, 381, and admission to the BA in Communication and Media Studies.
# None
#
# Communication and Media Studies 313 and admission to the Honours Program.
# None
#
# Consent of the School of Languages, Linguistics, Literatures and Cultures.
# None
#
# Chinese 205.
# {'and': [{'course': 'CHIN205'}]}
#
# Consent of the School of Languages, Linguistics, Literatures and Cultures.
# None
#
# Consent of the School of Languages, Linguistics, Literatures and Cultures.
# None
#
# Consent of the School of Languages, Linguistics, Literatures and Cultures.
# None
#
# Chinese 280.
# {'and': [{'course': 'CHIN280'}]}
#
# Chinese 207 or consent of the Department.
# None
#
# Chinese 301 or consent of the Department.
# None
#
# Consent of the School of Languages, Linguistics, Literatures and Cultures.
# None
#
# Chinese 304.
# {'and': [{'course': 'CHIN304'}]}
#
# Consent of the School of Languages, Linguistics, Literatures and Cultures.
# None
#
# Communication and Media Studies 595 and admission to the Honours Program.
# None
#
# Consent of the School of Languages, Linguistics, Literatures and Cultures.
# None
#
# Consent of the School of Languages, Linguistics, Literatures and Cultures.
# None
#
# Chinese 311.
# {'and': [{'course': 'CHIN311'}]}
#
# Chinese 303 or consent of the Department.
# None
#
# Chinese 331 or consent of the Department.
# None
#
# Consent of the School of Languages, Linguistics, Literatures and Cultures.
# None
#
# Chinese 334.
# {'and': [{'course': 'CHIN334'}]}
#
# Chinese 303.
# {'and': [{'course': 'CHIN303'}]}
#
# Chinese 207.
# {'and': [{'course': 'CHIN207'}]}
#
# Chinese 207 or consent of the School of Languages, Linguistics, Literatures and Cultures.
# None
#
# Chinese 303.
# {'and': [{'course': 'CHIN303'}]}
#
# Chinese 371.
# {'and': [{'course': 'CHIN371'}]}
#
# Chinese 333.
# {'and': [{'course': 'CHIN333'}]}
#
# Chinese 333.
# {'and': [{'course': 'CHIN333'}]}
#
# Chinese 303.
# {'and': [{'course': 'CHIN303'}]}
#
# Chinese 303.
# {'and': [{'course': 'CHIN303'}]}
#
# Chinese 303.
# {'and': [{'course': 'CHIN303'}]}
#
# Chinese 403.
# {'and': [{'course': 'CHIN403'}]}
#
# Chinese 303 or higher (excluding Chinese 317 and Chinese 355).
# None
#
# Chinese 403 or 431.
# {'or': [{'course': 'CHIN403'}, {'course': 'CHIN431'}]}
#
# Communication and Culture 201 or 301.
# {'or': [{'course': 'CMCL201'}, {'course': 'CMCL301'}]}
#
# Communication and Culture 301.
# {'and': [{'course': 'CMCL301'}]}
#
# Completion of 8.0 full-course equivalents.
# None
#
# Completion of at least 8.0 full-course equivalents.
# None
#
# 48 units (8.0 full-course equivalents) and consent of the Department of Communication, Media and Film.
# None
#
# Communication and Culture 507 and consent of the Department of Communication, Media and Film.
# None
#
# Chemistry 351; and Biology 311 or Medical Science 341.
# None
#
# Biochemistry 341 or 393; and Biology 311 or Medical Science 341; and Biology 331 or Medical Science 351.
# None
#
# Biology 311 or Medical Science 341; and Biology 331 or Medical Science 351; and Biochemistry 341 or 393.
# None
#
# Biology 311 or Medical Science 341.
# {'or': [{'course': 'BIOL311'}, {'course': 'MDSC341'}]}
#
# Biochemistry 393 and Cellular, Molecular and Microbial Biology 343; and Biology 311 or Medical Science 341; and Biology 331 or Medical Science 351.
# None
#
# Cellular, Molecular and Microbial Biology 343.
# {'and': [{'course': 'CMMB343'}]}
#
# Cellular, Molecular and Microbial Biology 343; and Biochemistry 341 or 393.
# None
#
# Cellular, Molecular and Microbial Biology 411 and admission to the Cellular, Molecular and Microbial Biology major or to the Biological Sciences Honours program.
# None
#
# Biology 331.
# {'and': [{'course': 'BIOL331'}]}
#
# Cellular, Molecular and Microbial Biology 403.
# {'and': [{'course': 'CMMB403'}]}
#
# 54 units and consent of the Department.
# None
#
# Computer Science 219 or 233 or 235.
# None
#
# Computer Science 313 and 319.
# {'and': [{'course': 'CPSC313'}, {'course': 'CPSC319'}]}
#
# 54 units and consent of the Department.
# None
#
# 54 units and consent of the Department.
# None
#
# 54 units and consent of the Department.
# None
#
# Computer Science 217 or Data Science 211.
# {'or': [{'course': 'CPSC217'}, {'course': 'DATA211'}]}
#
# Admission to Computer Science, Bioinformatics, or Natural Science with a primary concentration in Computer Science.
# None
#
# Computer Science 231 and admission to Computer Science, Bioinformatics, or Natural Science with a primary concentration in Computer Science.
# None
#
# Consent of the Department.
# None
#
# Computer Science 219 or 231.
# {'or': [{'course': 'CPSC219'}, {'course': 'CPSC231'}]}
#
# One of Computer Science 319 or 331, and consent of the Department.
# None
#
# Mathematics 271 or 273; and Philosophy 279 or 377; and 3 units from Computer Science 219, 233 or 235.
# None
#
# 3 units from Computer Science 219, 233, 235, Computer Engineering 335, 339 or Software Engineering for Engineers 337.
# None
#
# One of Computer Science 265 or 355 and one of Philosophy 279 or 377.
# None
#
# Mathematics 30-1, Mathematics 30-2, or Mathematics 31.
# None
#
# 3 units from Computer Science 251, Mathematics 271 or 273; and 3 units from Computer Science 219, 233, 235, Computer Engineering 335, 339 or Software Engineering for Engineers 337.
# None
#
# Computer Science 319 or 331.
# {'or': [{'course': 'CPSC319'}, {'course': 'CPSC331'}]}
#
# 3 units from Computer Science 219, 233 or 235; and Computer Science 251 or Statistics 213; and Mathematics 271 or 273; and 3 units from Mathematics 249, 265 or 275; and Philosophy 279 or 377.
# None
#
# 3 units from Computer Science 219, 233 or 235.
# None
#
# Computer Science 355 and Philosophy 279 or 377.
# None
#
# Computer Science 219, 233 or Data Science 311 and enrolment in one of the Majors in Computer Science, Bioinformatics, Electrical Engineering, Software Engineering, Computer Engineering, Natural Sciences with a primary concentration in Computer Science.
# None
#
# Consent of the Department.
# None
#
# Software Engineering 300 or 301.
# {'or': [{'course': 'SENG300'}, {'course': 'SENG301'}]}
#
# Computer Science 355.
# {'and': [{'course': 'CPSC355'}]}
#
# Computer Science 319 or 331; and Computer Science 355 or Computer Engineering 369.
# None
#
# Computer Science 331; and 313 or 351; and Mathematics 211 or 213; and 3 units from Mathematics 249, 265 or 275.
# None
#
# Computer Science 331 and 3 units from Computer Science 351, Mathematics 271, 273, 315 or Pure Mathematics 315.
# None
#
# Computer Science 325.
# {'and': [{'course': 'CPSC325'}]}
#
# Computer Science 319 or 331, and Pure Mathematics 329.
# None
#
# Computer Science 313 or 351; and Philosophy 279 or 377.
# None
#
# Computer Science 319 or 331; and Computer Science 355 or Computer Engineering 369.
# None
#
# Computer Science 319 or 331; Computer Science 313 or 351; and Philosophy 279 or 377.
# None
#
# Computer Science 319 or 331; and Mathematics 211 or 213; and 3 units from Mathematics 253, 267, 277, 283 or Applied Mathematics 219.
# None
#
# Computer Science 319 or 331; and Computer Science 355 or Computer Engineering 369.
# None
#
# Computer Science 355 and one of 319 or 331.
# None
#
# Computer Science 319 or 331.
# {'or': [{'course': 'CPSC319'}, {'course': 'CPSC331'}]}
#
# 3 units from Software Engineering 300, 301, Software Engineering 480 or Data Science 311.
# None
#
# ...
#
# Statistics 321.
# {'and': [{'course': 'STAT321'}]}
#
# 3 units from Mathematics 249, 265 or 275.
# None
#
# Statistics 321.
# {'and': [{'course': 'STAT321'}]}
#
# Statistics 321.
# {'and': [{'course': 'STAT321'}]}
#
# Mathematics 311 or 313, and 321 or any Statistics course, or consent of the Division.
# None
#
# Statistics 323.
# {'and': [{'course': 'STAT323'}]}
#
# 3 units from Statistics 217, 323, 327, Data Science 305, Engineering 319, Digital Engineering 319, Psychology 300, 301, 312, or Sociology 311.
# None
#
# 3 units from Statistics 217, 323, 327, Data Science 305, Engineering 319, Digital Engineering 319, Psychology 300, 301, 312, or Sociology 311.
# None
#
# Statistics 323 or Data Science 305; and Mathematics 211 or 213.
# None
#
# Statistics 323 or Data Science 305.
# {'or': [{'course': 'STAT323'}, {'course': 'DATA305'}]}
#
# Statistics 323 or Mathematics 323; and Mathematics 267 or 277 or 353 or 381.
# None
#
# Statistics 429.
# {'and': [{'course': 'STAT429'}]}
#
# Statistics 321.
# {'and': [{'course': 'STAT321'}]}
#
# 6 units from Statistics 423, 425, 429 and 505.
# None
#
# Statistics 323; and Mathematics 267 or 277.
# None
#
# Statistics 323.
# {'and': [{'course': 'STAT323'}]}
#
# Statistics 323.
# {'and': [{'course': 'STAT323'}]}
#
# Consent of the Department .
# None
#
# Statistics 323; and Mathematics 267 or 277.
# None
#
# Statistics 429.
# {'and': [{'course': 'STAT429'}]}
#
# STAT 429.
# {'and': [{'course': 'STAT429'}]}
#
# Statistics 429.
# {'and': [{'course': 'STAT429'}]}
#
# Engineering 200 and Sustainable Systems Engineering 301.
# {'and': [{'course': 'ENGG200'}, {'course': 'SUSE301'}]}
#
# Engineering 200.
# {'and': [{'course': 'ENGG200'}]}
#
# Engineering 200, 225 and Digital Engineering 233.
# None
#
# Engineering 233 or Digital Engineering 233
# {'or': [{'course': 'ENGG233'}, {'course': 'ENDG233'}]}
#
# Engineering 201 or 212; and Mathematics 275 or Applied Mathematics 217.
# None
#
# Sustainable Systems Engineering 300 and 301.
# {'and': [{'course': 'SUSE300'}, {'course': 'SUSE301'}]}
#
# Sustainable Systems Engineering 300.
# {'and': [{'course': 'SUSE300'}]}
#
# Sustainable Systems Engineering 300.
# {'and': [{'course': 'SUSE300'}]}
#
# Engineering 225 and 349.
# {'and': [{'course': 'ENGG225'}, {'course': 'ENGG349'}]}
#
# Sustainable Systems Engineering 463.
# {'and': [{'course': 'SUSE463'}]}
#
# Consent of the Department.
# None
#
# Energy and Environment Engineering 575.
# None
#
# Sustainable Systems Engineering 463 and Electrical Engineering 487.
# {'and': [{'course': 'SUSE463'}, {'course': 'ENEL487'}]}
#
# Sustainable Systems Engineering 463 and Energy and Environment, Engineering 503.
# {'and': [{'course': 'SUSE463'}, {'course': 'ENEE503'}]}
#
# Energy and Environment Engineering 575.
# None
#
# 3 units from Engineering 317, Mechanical Engineering 317 or Civil Engineering 317.
# None
#
# Sustainability Studies 201 or University 207.
# {'or': [{'course': 'SUST201'}, {'course': 'UNIV207'}]}
#
# Sustainability Studies 401.
# {'and': [{'course': 'SUST401'}]}
#
# Sustainability Studies 403 and enrolment in the embedded Certificate in Sustainability Studies.
# None
#
# Consent from the Academic Co-ordinator of Sustainability Studies.
# None
#
# Term Abroad Program 201 or consent of the Faculty of Humanities.
# None
#
# Admission to the Haskayne School of Business and 30 units.
# None
#
# 60 units.
# {'units': {'required': 60}}
#
# Admission to the Haskayne School of Business and successful completion of 10.0 full-course equivalents including Marketing 317 and Tourism Management 309.
# None
#
# Admission to the Haskayne School of Business and successful completion of 10.0 full-course equivalents.
# None
#
# Admission to the Haskayne School of Business and successful completion of 10.0 full-course equivalents including Finance 317 and Tourism Management 309.
# None
#
# Admission to the Haskayne School of Business and successful completion of 10 full-course equivalents including Tourism Management 309.
# None
#
# Admission to the Haskayne School of Business, and successful completion of 10 full-course equivalents including Accounting 217 or 317 and Tourism Management 309.
# None
#
# Admission to the Haskayne School of Business and successful completion of 10.0 full-course equivalents including Tourism Management 309.
# None
#
# Admission to the Haskayne School of Business and successful completion of 10 full-course equivalents including Tourism Management 309, or consent of the Haskayne School of Business.
# None
#
# 3 units from Urban Studies 253 or Geography 253.
# None
#
# 3 units from Urban Studies 253, Geography 253, Anthropology 379, Sociology 353.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Urban Studies 253.
# {'and': [{'course': 'UBST253'}]}
#
# 3 units from Geography 341, 351, 452 or 454.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Consent of the Department.
# None
#
# Admission to Urban Studies major or minor and completion of 75 units (12.5 full-course equivalents).
# None
#
# Consent of the Department.
# None
#
# 90 units and admission to the Urban Studies Major or Minor.
# None
#
# Consent of the Department.
# None
#
# Completed fewer than 18 units at the time of registration.
# None
#
# University 201 and completed fewer than 18 units at the time of registration.
# None
#
# Consent of the Faculty of Arts and completion of 30 units.
# None
#
# Completion of 18 units.
# None
#
# Consent of the student's faculty.
# None
#
# Consent of the student's faculty.
# None
#
# Consent of the student's faculty.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine Program.
# None
#
# Admission to the Doctor of Veterinary Medicine Program.
# None
#
# Admission to the Doctor of Veterinary Medicine Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Admission to the Doctor of Veterinary Medicine (DVM) Program.
# None
#
# Psychology 203 and admission to the Embedded Certificate in Mental Health and Wellbeing.
# None
#
# Wellbeing 300 and completion of 75 units.
# None
#
# Biology 30.
# {'and': [{'course': 'BIOL30'}]}
#
# Biology 30. Open only to students enrolled in the UC-Qatar Nursing Program.
# None
#
# Biology 30.
# {'and': [{'course': 'BIOL30'}]}
#
# Biology 371 or 233 or any two of Biology 231, 241 and 243 and completion of 9.5 full-course equivalents.
# None
#
# Biology 371 or 233 or any two of Biology 231, 241, 243 and completion of 9.5 full-course equivalents.
# None
#
# Biology 371.
# {'and': [{'course': 'BIOL371'}]}
#
# Biology 371.
# {'and': [{'course': 'BIOL371'}]}
#
# Biology 371.
# {'and': [{'course': 'BIOL371'}]}
#
# Biology 371 or 233.
# {'or': [{'course': 'BIOL371'}, {'course': 'BIOL233'}]}
#
# Biology 371.
# {'and': [{'course': 'BIOL371'}]}
#
# Biology 331.
# {'and': [{'course': 'BIOL331'}]}
#
# Zoology 461.
# {'and': [{'course': 'ZOOL461'}]}
#
# Zoology 375 or 401.
# {'or': [{'course': 'ZOOL375'}, {'course': 'ZOOL401'}]}
#
# Biology 313 and one of Biology 371 or Zoology 377.
# None
#
# Biology 313 and one of Biology 371 or Zoology 377.
# None
#
# 54 units and consent of the Department.
# None
#
# 54 units and consent of the Department.
# None
#
# 54 units and consent of the Department.
# None
#
# Zoology 379 or 403.
# {'or': [{'course': 'ZOOL379'}, {'course': 'ZOOL403'}]}
#
# Biology 315, 72 units and consent of the Department.
# None
